# %%
from pathlib import Path
import pandas as pd

# %%
raw_data = (Path.cwd() / '..'/ '..' / 'gender-recognation' / 'data' / 'raw').resolve()

# %%
files = [i for i in raw_data.glob('*')]

# %%
file = files[0]

# %%
type(None)
# Out:
# NoneType

# %%
df = None
for file in files:
    temp_waves = pd.DataFrame([i for i in file.rglob('wav/*')])
    readme = [i for i in file.rglob('*/README')][0]
    info = pd.read_csv(readme,sep=':',header=None,names=['k','v'])

    temp_waves['user_name'] = info[info.k == 'User Name'].v.values[0]
    temp_waves['gender'] = info[info.k == 'Gender'].v.values[0]
    if type(df) == type(None):
        df = temp_waves
    else:
        df = pd.concat([df,temp_waves])

# %%
df
# Out:
#                                                     0   user_name gender
# 0   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 1   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 2   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 3   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 4   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 5   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 6   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 7   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 8   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 9   F:\Data Projects\gender-recognition-by-voice\g...      1snoke   Male
# 0   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 1   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 2   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 3   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 4   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 5   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 6   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 7   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 8   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 9   F:\Data Projects\gender-recognition-by-voice\g...  23yipikaye   Male
# 0   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 1   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 2   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 3   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 4   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 5   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 6   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 7   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 8   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# 9   F:\Data Projects\gender-recognition-by-voice\g...   2old2play   Male
# ..                                                ...         ...    ...
# 0   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 1   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 2   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 3   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 4   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 5   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 6   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 7   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 8   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 9   F:\Data Projects\gender-recognition-by-voice\g...          AT   Male
# 0   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 1   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 2   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 3   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 4   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 5   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 6   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 7   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 8   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 9   F:\Data Projects\gender-recognition-by-voice\g...   _caustic_   Male
# 0   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 1   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 2   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 3   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 4   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 5   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 6   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 7   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 8   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
# 9   F:\Data Projects\gender-recognition-by-voice\g...        _r2h   Male
#
# [130 rows x 3 columns]
